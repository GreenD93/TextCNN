# %% [markdown]
# ## Embedding Layler

# %%
import numpy as np
from gensim.models import Word2Vec, KeyedVectors
import os
import params

embed_lookup = KeyedVectors.load_word2vec_format(params.w2v_path, 
                                                 binary=True)

print('변경 전')
print(embed_lookup.vectors.shape)
# 
# # <pad> vector, index 추가
# 
pad_vectors = np.zeros_like(embed_lookup.vectors[0])
embed_lookup.vectors = np.insert(embed_lookup.vectors, 0, pad_vectors,axis=0)
embed_lookup.index2word.insert(0,'<pad>')
print('변경 후')
print(embed_lookup.vectors.shape)
# Out:
# 변경 전
# (41721, 200)
# 변경 후
# (41722, 200)

# %%
# store pretrained vocab
pretrained_words = []
for word in embed_lookup.vocab:
    pretrained_words.append(word)

pretrained_words.insert(0,'<pad>')

# %%
row_idx = 1

# get word/embedding in that row
word = pretrained_words[row_idx] # get words by index
embedding = embed_lookup[word] # embeddings by word

# vocab and embedding info
print("Size of Vocab: {}\n".format(len(pretrained_words)))
print('Word in vocab: {}\n'.format(word))
print('Length of embedding: {}\n'.format(len(embedding)))
#print('Associated embedding: \n', embedding)
# Out:
# Size of Vocab: 41722
#
# Word in vocab: g
#
# Length of embedding: 200

# %%
# print a few common words
for i in range(5):
    print(pretrained_words[i])
# Out:
# <pad>
# g
# x
# 개
# 가공식품

# %% [markdown]
# ## Data preprocessing

# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

train_df = pd.read_csv('data/tarin_prodNm.csv', encoding='euc-kr')
train_df = shuffle(train_df, random_state=33).reset_index(drop=True)
train_df.head()
# Out:
#                                   prodNm                       cleaned_prodNm  \
# 0  피아토스 감자칩 바베큐맛 85g 피아토스,감자칩,수입감자칩,수입과자  피아토스 감자칩 바베큐맛 g 피아토스 감자칩 수입감자칩 수입과자
# 1           청우 왕사탕 500g/사탕/왕사탕/캔디/왕캔디/간식            청우 왕사탕 g 사탕 왕사탕 캔디 왕캔디 간식
# 2      ACER Swift3 SF314-52G-59WM용 저반사필름         acer swift sf - g- wm용 저반사필름
# 3    앤디스 크림 데 민트 띤 132g 고급초콜렛,수입초콜렛,수입사탕     앤디스 크림 데 민트 띤 g 고급초콜렛 수입초콜렛 수입사탕
# 4            맥심 오리지널 20T 24입 커피/차/꿀 무료배송              맥심 오리지널 t 입 커피 차 꿀 무료배송
#
#    label
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0

# %%
cleaned_prodNm = train_df['cleaned_prodNm'].values.tolist()
encoded_labels = train_df['label'].values

# %%
# convert prodNm to tokens

def tokenize_all_prodNm(embed_lookup, cleaned_prodNm):
    
    # split each prodNm into a list of words
    prodNm_words = [prodNm.split() for prodNm in cleaned_prodNm]

    tokenized_prodNms = []
    for prodNm in prodNm_words:
        ints = []
        for word in prodNm:
            try:
                idx = embed_lookup.vocab[word].index +1
            except: 
                idx = 0
            ints.append(idx)
            
        tokenized_prodNms.append(ints)
    
    return tokenized_prodNms

tokenize_all_cleaned_prodNms = tokenize_all_prodNm(embed_lookup, cleaned_prodNm)
tokenize_all_cleaned_prodNms[0]
# Out:
# [4029, 480, 977, 1, 4029, 480, 6626, 183]

# %%
# testing code and printing a tokenized review
print(tokenize_all_cleaned_prodNms[0])
# Out:
# [4029, 480, 977, 1, 4029, 480, 6626, 183]

# %%
# fill padding into toekized_prodNms

def pad_features(tokenize_all_cleaned_prodNms, seq_length):
    ''' Return features of tokenized_prodNms, where each review is padded with 0's 
        or truncated to the input seq_length.
    '''
    
    # getting the correct rows x cols shape
    features = np.zeros((len(tokenize_all_cleaned_prodNms), seq_length), dtype=int)

    # for each review, I grab that review and 
    for i, row in enumerate(tokenize_all_cleaned_prodNms):
        features[i, -len(row):] = np.array(row)[:seq_length]
    
    return features

features = pad_features(tokenize_all_cleaned_prodNms,15)
features[0]
# Out:
# array([   0,    0,    0,    0,    0,    0,    0, 4029,  480,  977,    1,
#        4029,  480, 6626,  183])

# %% [markdown]
# ## Data loader

# %%
split_frac = 0.8

## split data into training, validation, and test data (features and labels, x and y)

split_idx = int(len(features)*split_frac)
train_x, remaining_x = features[:split_idx], features[split_idx:]
train_y, remaining_y = encoded_labels[:split_idx], encoded_labels[split_idx:]

test_idx = int(len(remaining_x)*0.5)
val_x, test_x = remaining_x[:test_idx], remaining_x[test_idx:]
val_y, test_y = remaining_y[:test_idx], remaining_y[test_idx:]

## print out the shapes of your resultant feature data
print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(11411, 15)
# Validation set: 	(1426, 15)
# Test set: 		(1427, 15)

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# create Tensor datasets
train_data = TensorDataset(torch.from_numpy(train_x), torch.from_numpy(train_y))
valid_data = TensorDataset(torch.from_numpy(val_x), torch.from_numpy(val_y))
test_data = TensorDataset(torch.from_numpy(test_x), torch.from_numpy(test_y))

# dataloaders
batch_size = 12

# shuffling and batching data
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
valid_loader = DataLoader(valid_data, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size)

# %%
# First checking if GPU is available
train_on_gpu=torch.cuda.is_available()

if(train_on_gpu):
    print('Training on GPU.')
else:
    print('No GPU available, training on CPU.')
# Out:
# Training on GPU.

# %% [markdown]
# ## Define model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# channel, height, width
class ProdnmCNN(nn.Module):
    """
    The embedding layer + CNN model that will be used to perform sentiment analysis.
    """

    def __init__(self, embed_model, vocab_size, output_size, embedding_dim,
                 num_filters=100, kernel_sizes=[3, 4, 5], freeze_embeddings=True, drop_prob=0.5):
        """
        Initialize the model by setting up the layers.
        """
        super(ProdnmCNN, self).__init__()

        # set class vars
        self.num_filters = num_filters
        self.embedding_dim = embedding_dim

        # 1. embedding layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        # set weights to pre-trained
        self.embedding.weight = nn.Parameter(torch.from_numpy(embed_model.vectors))  # all vectors

        #         # (optional) freeze embedding weights
        #         if freeze_embeddings:
        #             self.embedding.requires_grad = False

        # 2. convolutional layers
        self.convs_1d = nn.ModuleList([
            nn.Conv2d(1, num_filters, (k, embedding_dim), padding=(k - 2, 0))
            for k in kernel_sizes])

        # 3. final, fully-connected layer for classification
        self.fc = nn.Linear(len(kernel_sizes) * num_filters, output_size)

        # 4. dropout and sigmoid layers
        self.dropout = nn.Dropout(drop_prob)
        self.sig = nn.Sigmoid()

    def conv_and_pool(self, x, conv):
        """
        Convolutional + max pooling layer
        """
        # squeeze last dim to get size: (batch_size, num_filters, conv_seq_length)
        # conv_seq_length will be ~ 200
        x = F.relu(conv(x)).squeeze(3)

        # 1D pool over conv_seq_length
        # squeeze to get size: (batch_size, num_filters)
        x_max = F.max_pool1d(x, x.size(2)).squeeze(2)
        return x_max

    def forward(self, x):
        """
        Defines how a batch of inputs, x, passes through the model layers.
        Returns a single, sigmoid-activated class score as output.
        """
        # embedded vectors
        embeds = self.embedding(x)  # (batch_size, seq_length, embedding_dim)
        # embeds.unsqueeze(1) creates a channel dimension that conv layers expect
        embeds = embeds.unsqueeze(1)

        # get output of each conv-pool layer
        conv_results = [self.conv_and_pool(embeds, conv) for conv in self.convs_1d]

        # concatenate results and add dropout
        x = torch.cat(conv_results, 1)
        x = self.dropout(x)

        # final logit
        logit = self.fc(x)

        # sigmoid-activated --> a class score
        return self.sig(logit)

# %% [markdown]
# ## Training

# %%
# Instantiate the model w/ hyperparams

vocab_size = len(pretrained_words)
output_size = 1 # binary class (1 or 0)
embedding_dim = len(embed_lookup[pretrained_words[1]]) # 300-dim vectors
num_filters = 100
kernel_sizes = [3, 4, 5]

net = ProdnmCNN(embed_lookup, vocab_size, output_size, embedding_dim,
                   num_filters, kernel_sizes)

print(net)

# loss and optimization functions
lr=0.001

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(net.parameters(), lr=lr)
# Out:
# ProdnmCNN(
#   (embedding): Embedding(41722, 200)
#   (convs_1d): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(3, 200), stride=(1, 1), padding=(1, 0))
#     (1): Conv2d(1, 100, kernel_size=(4, 200), stride=(1, 1), padding=(2, 0))
#     (2): Conv2d(1, 100, kernel_size=(5, 200), stride=(1, 1), padding=(3, 0))
#   )
#   (fc): Linear(in_features=300, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (sig): Sigmoid()
# )

# %%
# training loop
def train(net, train_loader, epochs, print_every=100):

    # move model to GPU, if available
    if(train_on_gpu):
        net.cuda()

    counter = 0 # for printing
    
    # train for some number of epochs
    net.train()
    for e in range(epochs):

        # batch loop
        for inputs, labels in train_loader:
            counter += 1
            
            if(train_on_gpu):
                inputs, labels = inputs.cuda(), labels.cuda()

            # zero accumulated gradients
            net.zero_grad()

            # get the output from the model
            output = net(inputs)

            # calculate the loss and perform backprop
            loss = criterion(output.squeeze(), labels.float())
            loss.backward()
            optimizer.step()

            # loss stats
            if counter % print_every == 0:
                # Get validation loss
                val_losses = []
                num_correct = 0
                
                net.eval()
                
                for inputs, labels in valid_loader:

                    if(train_on_gpu):
                        inputs, labels = inputs.cuda(), labels.cuda()

                    output = net(inputs)
                    val_loss = criterion(output.squeeze(), labels.float())
                    val_losses.append(val_loss.item())
                    
                    ## val acc
                    # convert output probabilities to predicted class (0 or 1)
                    pred = torch.round(output.squeeze())  # rounds to the nearest integer

                    # compare predictions to true label
                    correct_tensor = pred.eq(labels.float().view_as(pred))
                    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
                    num_correct += np.sum(correct)
                    
                net.train()
                
                print("Epoch: {}/{}...".format(e+1, epochs),
                      "Step: {}...".format(counter),
                      "Loss: {:.6f}...".format(loss.item()),
                      "Val Loss: {:.6f}".format(np.mean(val_losses)),
                      "Val acc: {:.3f}".format(np.mean(num_correct/len(valid_loader.dataset))))

# %%
import time
# training params

start = time.time()

epochs = 20 # this is approx where I noticed the validation loss stop decreasing
print_every = 100

train(net, train_loader, epochs, print_every=print_every)

end = time.time()

print('turnaround time : {0}'.format(end - start))
# Out:
# Epoch: 1/20... Step: 100... Loss: 0.195344... Val Loss: 0.269833 Val acc: 0.889
# Epoch: 1/20... Step: 200... Loss: 0.330087... Val Loss: 0.232230 Val acc: 0.904
# Epoch: 1/20... Step: 300... Loss: 0.121067... Val Loss: 0.224658 Val acc: 0.894
# Epoch: 1/20... Step: 400... Loss: 0.218031... Val Loss: 0.240206 Val acc: 0.901
# Epoch: 1/20... Step: 500... Loss: 0.176410... Val Loss: 0.240101 Val acc: 0.906
# Epoch: 1/20... Step: 600... Loss: 0.139371... Val Loss: 0.175175 Val acc: 0.924
# Epoch: 1/20... Step: 700... Loss: 0.052601... Val Loss: 0.183689 Val acc: 0.914
# Epoch: 1/20... Step: 800... Loss: 0.068933... Val Loss: 0.167358 Val acc: 0.935
# Epoch: 1/20... Step: 900... Loss: 0.057072... Val Loss: 0.163043 Val acc: 0.938
# Epoch: 2/20... Step: 1000... Loss: 0.066954... Val Loss: 0.145152 Val acc: 0.941
# Epoch: 2/20... Step: 1100... Loss: 0.122104... Val Loss: 0.166225 Val acc: 0.931
# Epoch: 2/20... Step: 1200... Loss: 0.141533... Val Loss: 0.144449 Val acc: 0.939
# Epoch: 2/20... Step: 1300... Loss: 0.177664... Val Loss: 0.146894 Val acc: 0.938
# Epoch: 2/20... Step: 1400... Loss: 0.094215... Val Loss: 0.137286 Val acc: 0.944
# Epoch: 2/20... Step: 1500... Loss: 0.343553... Val Loss: 0.125927 Val acc: 0.952
# Epoch: 2/20... Step: 1600... Loss: 0.133868... Val Loss: 0.124058 Val acc: 0.954
# Epoch: 2/20... Step: 1700... Loss: 0.075679... Val Loss: 0.129549 Val acc: 0.954
# Epoch: 2/20... Step: 1800... Loss: 0.002166... Val Loss: 0.127124 Val acc: 0.959
# Epoch: 2/20... Step: 1900... Loss: 0.018434... Val Loss: 0.107168 Val acc: 0.957
# Epoch: 3/20... Step: 2000... Loss: 0.179544... Val Loss: 0.107534 Val acc: 0.958
# Epoch: 3/20... Step: 2100... Loss: 0.176105... Val Loss: 0.112298 Val acc: 0.955
# Epoch: 3/20... Step: 2200... Loss: 0.064734... Val Loss: 0.109209 Val acc: 0.960
# Epoch: 3/20... Step: 2300... Loss: 0.000787... Val Loss: 0.119336 Val acc: 0.959
# Epoch: 3/20... Step: 2400... Loss: 0.004348... Val Loss: 0.121501 Val acc: 0.956
# Epoch: 3/20... Step: 2500... Loss: 0.276579... Val Loss: 0.114641 Val acc: 0.964
# Epoch: 3/20... Step: 2600... Loss: 0.006795... Val Loss: 0.127532 Val acc: 0.954
# Epoch: 3/20... Step: 2700... Loss: 0.054159... Val Loss: 0.116628 Val acc: 0.957
# Epoch: 3/20... Step: 2800... Loss: 0.018376... Val Loss: 0.133568 Val acc: 0.952
# Epoch: 4/20... Step: 2900... Loss: 0.003659... Val Loss: 0.118479 Val acc: 0.959
# Epoch: 4/20... Step: 3000... Loss: 0.025792... Val Loss: 0.127563 Val acc: 0.962
# Epoch: 4/20... Step: 3100... Loss: 0.003013... Val Loss: 0.135633 Val acc: 0.956
# Epoch: 4/20... Step: 3200... Loss: 0.002472... Val Loss: 0.136157 Val acc: 0.958
# Epoch: 4/20... Step: 3300... Loss: 0.006773... Val Loss: 0.125474 Val acc: 0.961
# Epoch: 4/20... Step: 3400... Loss: 0.014415... Val Loss: 0.128827 Val acc: 0.958
# Epoch: 4/20... Step: 3500... Loss: 0.502749... Val Loss: 0.129708 Val acc: 0.961
# Epoch: 4/20... Step: 3600... Loss: 0.007691... Val Loss: 0.140864 Val acc: 0.955
# Epoch: 4/20... Step: 3700... Loss: 0.000194... Val Loss: 0.126454 Val acc: 0.959
# Epoch: 4/20... Step: 3800... Loss: 0.000455... Val Loss: 0.130652 Val acc: 0.961
# Epoch: 5/20... Step: 3900... Loss: 0.002230... Val Loss: 0.147244 Val acc: 0.959
# Epoch: 5/20... Step: 4000... Loss: 0.480311... Val Loss: 0.148000 Val acc: 0.961
# Epoch: 5/20... Step: 4100... Loss: 0.002656... Val Loss: 0.159855 Val acc: 0.953
# Epoch: 5/20... Step: 4200... Loss: 0.122161... Val Loss: 0.147291 Val acc: 0.957
# Epoch: 5/20... Step: 4300... Loss: 0.000674... Val Loss: 0.165146 Val acc: 0.957
# Epoch: 5/20... Step: 4400... Loss: 0.001795... Val Loss: 0.164519 Val acc: 0.956
# Epoch: 5/20... Step: 4500... Loss: 0.012994... Val Loss: 0.161666 Val acc: 0.957
# Epoch: 5/20... Step: 4600... Loss: 0.011087... Val Loss: 0.156488 Val acc: 0.961
# Epoch: 5/20... Step: 4700... Loss: 0.004302... Val Loss: 0.156476 Val acc: 0.960
# Epoch: 6/20... Step: 4800... Loss: 0.000115... Val Loss: 0.164465 Val acc: 0.962
# Epoch: 6/20... Step: 4900... Loss: 0.002236... Val Loss: 0.168556 Val acc: 0.959
# Epoch: 6/20... Step: 5000... Loss: 0.084783... Val Loss: 0.177482 Val acc: 0.959
# Epoch: 6/20... Step: 5100... Loss: 0.000199... Val Loss: 0.185069 Val acc: 0.959
# Epoch: 6/20... Step: 5200... Loss: 0.000070... Val Loss: 0.184530 Val acc: 0.960
# Epoch: 6/20... Step: 5300... Loss: 0.000884... Val Loss: 0.176107 Val acc: 0.961
# Epoch: 6/20... Step: 5400... Loss: 0.000453... Val Loss: 0.182192 Val acc: 0.961
# Epoch: 6/20... Step: 5500... Loss: 0.001535... Val Loss: 0.201555 Val acc: 0.957
# Epoch: 6/20... Step: 5600... Loss: 0.000006... Val Loss: 0.182080 Val acc: 0.958
# Epoch: 6/20... Step: 5700... Loss: 0.001574... Val Loss: 0.194754 Val acc: 0.959
# Epoch: 7/20... Step: 5800... Loss: 0.119107... Val Loss: 0.186542 Val acc: 0.958
# Epoch: 7/20... Step: 5900... Loss: 0.000301... Val Loss: 0.192188 Val acc: 0.961
# Epoch: 7/20... Step: 6000... Loss: 0.000015... Val Loss: 0.189481 Val acc: 0.961
# Epoch: 7/20... Step: 6100... Loss: 0.008571... Val Loss: 0.206561 Val acc: 0.961
# Epoch: 7/20... Step: 6200... Loss: 0.000086... Val Loss: 0.204487 Val acc: 0.962
# Epoch: 7/20... Step: 6300... Loss: 0.000192... Val Loss: 0.199486 Val acc: 0.960
# Epoch: 7/20... Step: 6400... Loss: 0.000002... Val Loss: 0.215110 Val acc: 0.962
# Epoch: 7/20... Step: 6500... Loss: 0.002139... Val Loss: 0.226492 Val acc: 0.959
# Epoch: 7/20... Step: 6600... Loss: 0.000002... Val Loss: 0.222675 Val acc: 0.963
# Epoch: 8/20... Step: 6700... Loss: 0.000000... Val Loss: 0.223951 Val acc: 0.960
# Epoch: 8/20... Step: 6800... Loss: 0.000009... Val Loss: 0.232387 Val acc: 0.963
# Epoch: 8/20... Step: 6900... Loss: 0.000009... Val Loss: 0.220279 Val acc: 0.957
# Epoch: 8/20... Step: 7000... Loss: 0.000020... Val Loss: 0.217458 Val acc: 0.958
# Epoch: 8/20... Step: 7100... Loss: 0.000123... Val Loss: 0.218452 Val acc: 0.958
# Epoch: 8/20... Step: 7200... Loss: 0.000241... Val Loss: 0.273180 Val acc: 0.953
# Epoch: 8/20... Step: 7300... Loss: 0.000004... Val Loss: 0.252580 Val acc: 0.954
# Epoch: 8/20... Step: 7400... Loss: 0.000008... Val Loss: 0.243081 Val acc: 0.953
# Epoch: 8/20... Step: 7500... Loss: 0.000043... Val Loss: 0.233031 Val acc: 0.961
# Epoch: 8/20... Step: 7600... Loss: 0.000042... Val Loss: 0.263603 Val acc: 0.959
# Epoch: 9/20... Step: 7700... Loss: 0.000332... Val Loss: 0.241359 Val acc: 0.956
# Epoch: 9/20... Step: 7800... Loss: 0.000000... Val Loss: 0.264470 Val acc: 0.960
# Epoch: 9/20... Step: 7900... Loss: 0.000225... Val Loss: 0.267364 Val acc: 0.958
# Epoch: 9/20... Step: 8000... Loss: 0.000003... Val Loss: 0.318288 Val acc: 0.950
# Epoch: 9/20... Step: 8100... Loss: 0.001167... Val Loss: 0.290602 Val acc: 0.954
# Epoch: 9/20... Step: 8200... Loss: 0.002161... Val Loss: 0.284844 Val acc: 0.955
# Epoch: 9/20... Step: 8300... Loss: 0.000058... Val Loss: 0.258694 Val acc: 0.958
# Epoch: 9/20... Step: 8400... Loss: 0.000039... Val Loss: 0.293695 Val acc: 0.957
# Epoch: 9/20... Step: 8500... Loss: 0.000314... Val Loss: 0.298767 Val acc: 0.958
# Epoch: 10/20... Step: 8600... Loss: 0.000102... Val Loss: 0.255312 Val acc: 0.955
# Epoch: 10/20... Step: 8700... Loss: 0.000004... Val Loss: 0.272784 Val acc: 0.959
# Epoch: 10/20... Step: 8800... Loss: 0.000013... Val Loss: 0.333725 Val acc: 0.957
# Epoch: 10/20... Step: 8900... Loss: 0.000115... Val Loss: 0.308748 Val acc: 0.957
# Epoch: 10/20... Step: 9000... Loss: 0.000004... Val Loss: 0.298475 Val acc: 0.959
# Epoch: 10/20... Step: 9100... Loss: 0.000000... Val Loss: 0.275151 Val acc: 0.958
# Epoch: 10/20... Step: 9200... Loss: 0.000001... Val Loss: 0.288406 Val acc: 0.953
# Epoch: 10/20... Step: 9300... Loss: 0.001454... Val Loss: 0.316874 Val acc: 0.956
# Epoch: 10/20... Step: 9400... Loss: 0.000006... Val Loss: 0.300490 Val acc: 0.955
# Epoch: 10/20... Step: 9500... Loss: 0.000000... Val Loss: 0.376849 Val acc: 0.949
# Epoch: 11/20... Step: 9600... Loss: 0.000000... Val Loss: 0.313928 Val acc: 0.954
# Epoch: 11/20... Step: 9700... Loss: 0.000073... Val Loss: 0.318761 Val acc: 0.956
# Epoch: 11/20... Step: 9800... Loss: 0.000002... Val Loss: 0.341058 Val acc: 0.954
# Epoch: 11/20... Step: 9900... Loss: 0.081114... Val Loss: 0.319784 Val acc: 0.957
# Epoch: 11/20... Step: 10000... Loss: 0.000217... Val Loss: 0.313110 Val acc: 0.958
# Epoch: 11/20... Step: 10100... Loss: 0.000422... Val Loss: 0.417313 Val acc: 0.945
# Epoch: 11/20... Step: 10200... Loss: 0.000000... Val Loss: 0.354246 Val acc: 0.955
# Epoch: 11/20... Step: 10300... Loss: 0.000367... Val Loss: 0.361140 Val acc: 0.954
# Epoch: 11/20... Step: 10400... Loss: 0.000121... Val Loss: 0.355447 Val acc: 0.959
# Epoch: 12/20... Step: 10500... Loss: 0.000014... Val Loss: 0.394901 Val acc: 0.952
# Epoch: 12/20... Step: 10600... Loss: 0.000002... Val Loss: 0.359179 Val acc: 0.956
# Epoch: 12/20... Step: 10700... Loss: 0.000000... Val Loss: 0.399474 Val acc: 0.952
# Epoch: 12/20... Step: 10800... Loss: 0.000000... Val Loss: 0.445023 Val acc: 0.945
# Epoch: 12/20... Step: 10900... Loss: 0.000000... Val Loss: 0.353196 Val acc: 0.961
# Epoch: 12/20... Step: 11000... Loss: 0.000000... Val Loss: 0.359193 Val acc: 0.958
# Epoch: 12/20... Step: 11100... Loss: 0.000001... Val Loss: 0.359353 Val acc: 0.959
# Epoch: 12/20... Step: 11200... Loss: 0.000003... Val Loss: 0.386355 Val acc: 0.955
# Epoch: 12/20... Step: 11300... Loss: 0.000006... Val Loss: 0.366932 Val acc: 0.952
# Epoch: 12/20... Step: 11400... Loss: 0.000000... Val Loss: 0.394883 Val acc: 0.955
# Epoch: 13/20... Step: 11500... Loss: 0.000001... Val Loss: 0.373811 Val acc: 0.957
# Epoch: 13/20... Step: 11600... Loss: 0.000012... Val Loss: 0.413745 Val acc: 0.955
# Epoch: 13/20... Step: 11700... Loss: 0.000000... Val Loss: 0.394908 Val acc: 0.957
# Epoch: 13/20... Step: 11800... Loss: 0.000016... Val Loss: 0.523797 Val acc: 0.950
# Epoch: 13/20... Step: 11900... Loss: 0.000000... Val Loss: 0.415841 Val acc: 0.952
# Epoch: 13/20... Step: 12000... Loss: 0.000000... Val Loss: 0.398500 Val acc: 0.954
# Epoch: 13/20... Step: 12100... Loss: 0.000000... Val Loss: 0.409909 Val acc: 0.955
# Epoch: 13/20... Step: 12200... Loss: 0.000000... Val Loss: 0.427851 Val acc: 0.959
# Epoch: 13/20... Step: 12300... Loss: 0.000000... Val Loss: 0.435872 Val acc: 0.955
# Epoch: 14/20... Step: 12400... Loss: 0.000000... Val Loss: 0.443893 Val acc: 0.954
# Epoch: 14/20... Step: 12500... Loss: 0.000000... Val Loss: 0.544786 Val acc: 0.954
# Epoch: 14/20... Step: 12600... Loss: 0.000000... Val Loss: 0.494461 Val acc: 0.955
# Epoch: 14/20... Step: 12700... Loss: 0.000000... Val Loss: 0.511341 Val acc: 0.959
# Epoch: 14/20... Step: 12800... Loss: 0.000000... Val Loss: 0.500349 Val acc: 0.957
# Epoch: 14/20... Step: 12900... Loss: 0.000002... Val Loss: 0.485077 Val acc: 0.955
# Epoch: 14/20... Step: 13000... Loss: 0.000000... Val Loss: 0.543997 Val acc: 0.950
# Epoch: 14/20... Step: 13100... Loss: 0.000001... Val Loss: 0.464269 Val acc: 0.952
# Epoch: 14/20... Step: 13200... Loss: 0.000000... Val Loss: 0.514434 Val acc: 0.952
# Epoch: 14/20... Step: 13300... Loss: 0.000000... Val Loss: 0.566613 Val acc: 0.950
# Epoch: 15/20... Step: 13400... Loss: 0.000269... Val Loss: 0.532133 Val acc: 0.950
# Epoch: 15/20... Step: 13500... Loss: 0.000000... Val Loss: 0.494683 Val acc: 0.954
# Epoch: 15/20... Step: 13600... Loss: 0.000000... Val Loss: 0.478195 Val acc: 0.957
# Epoch: 15/20... Step: 13700... Loss: 0.000000... Val Loss: 0.517353 Val acc: 0.956
# Epoch: 15/20... Step: 13800... Loss: 0.000000... Val Loss: 0.507553 Val acc: 0.955
# Epoch: 15/20... Step: 13900... Loss: 0.000000... Val Loss: 0.471874 Val acc: 0.954
# Epoch: 15/20... Step: 14000... Loss: 0.000000... Val Loss: 0.467273 Val acc: 0.954
# Epoch: 15/20... Step: 14100... Loss: 0.000000... Val Loss: 0.446458 Val acc: 0.955
# Epoch: 15/20... Step: 14200... Loss: 0.000001... Val Loss: 0.444759 Val acc: 0.952
# Epoch: 16/20... Step: 14300... Loss: 0.000000... Val Loss: 0.477249 Val acc: 0.955
# Epoch: 16/20... Step: 14400... Loss: 0.002255... Val Loss: 0.457890 Val acc: 0.953
# Epoch: 16/20... Step: 14500... Loss: 0.000003... Val Loss: 0.448570 Val acc: 0.954
# Epoch: 16/20... Step: 14600... Loss: 0.000000... Val Loss: 0.497870 Val acc: 0.953
# Epoch: 16/20... Step: 14700... Loss: 0.000000... Val Loss: 0.513961 Val acc: 0.956
# Epoch: 16/20... Step: 14800... Loss: 0.000000... Val Loss: 0.499667 Val acc: 0.952
# Epoch: 16/20... Step: 14900... Loss: 0.000000... Val Loss: 0.496305 Val acc: 0.952
# Epoch: 16/20... Step: 15000... Loss: 0.000003... Val Loss: 0.543943 Val acc: 0.953
# Epoch: 16/20... Step: 15100... Loss: 0.000000... Val Loss: 0.543171 Val acc: 0.955
# Epoch: 16/20... Step: 15200... Loss: 0.000000... Val Loss: 0.520055 Val acc: 0.950
# Epoch: 17/20... Step: 15300... Loss: 0.000000... Val Loss: 0.540013 Val acc: 0.951
# Epoch: 17/20... Step: 15400... Loss: 0.000003... Val Loss: 0.492302 Val acc: 0.953
# Epoch: 17/20... Step: 15500... Loss: 0.000000... Val Loss: 0.504931 Val acc: 0.955
# Epoch: 17/20... Step: 15600... Loss: 0.000106... Val Loss: 0.498852 Val acc: 0.954
# Epoch: 17/20... Step: 15700... Loss: 0.000003... Val Loss: 0.498959 Val acc: 0.957
# Epoch: 17/20... Step: 15800... Loss: 0.000000... Val Loss: 0.526402 Val acc: 0.953
# Epoch: 17/20... Step: 15900... Loss: 0.000000... Val Loss: 0.558131 Val acc: 0.952
# Epoch: 17/20... Step: 16000... Loss: 0.000000... Val Loss: 0.556743 Val acc: 0.952
# Epoch: 17/20... Step: 16100... Loss: 0.000000... Val Loss: 0.529765 Val acc: 0.953
# Epoch: 18/20... Step: 16200... Loss: 0.000000... Val Loss: 0.492649 Val acc: 0.954
# Epoch: 18/20... Step: 16300... Loss: 0.000000... Val Loss: 0.489365 Val acc: 0.954
# Epoch: 18/20... Step: 16400... Loss: 0.000000... Val Loss: 0.493578 Val acc: 0.953
# Epoch: 18/20... Step: 16500... Loss: 0.000045... Val Loss: 0.539646 Val acc: 0.948
# Epoch: 18/20... Step: 16600... Loss: 0.000000... Val Loss: 0.504724 Val acc: 0.954
# Epoch: 18/20... Step: 16700... Loss: 0.000001... Val Loss: 0.563913 Val acc: 0.949
# Epoch: 18/20... Step: 16800... Loss: 0.000000... Val Loss: 0.504058 Val acc: 0.953
# Epoch: 18/20... Step: 16900... Loss: 0.000000... Val Loss: 0.523627 Val acc: 0.952
# Epoch: 18/20... Step: 17000... Loss: 0.000000... Val Loss: 0.519085 Val acc: 0.950
# Epoch: 18/20... Step: 17100... Loss: 0.000000... Val Loss: 0.593985 Val acc: 0.956
# Epoch: 19/20... Step: 17200... Loss: 0.000000... Val Loss: 0.589170 Val acc: 0.952
# Epoch: 19/20... Step: 17300... Loss: 0.000000... Val Loss: 0.581912 Val acc: 0.953
# Epoch: 19/20... Step: 17400... Loss: 0.000000... Val Loss: 0.569801 Val acc: 0.952
# Epoch: 19/20... Step: 17500... Loss: 0.000000... Val Loss: 0.583323 Val acc: 0.952
# Epoch: 19/20... Step: 17600... Loss: 0.000000... Val Loss: 0.572235 Val acc: 0.957
# Epoch: 19/20... Step: 17700... Loss: 0.000000... Val Loss: 0.579879 Val acc: 0.955
# Epoch: 19/20... Step: 17800... Loss: 0.000000... Val Loss: 0.579922 Val acc: 0.955
# Epoch: 19/20... Step: 17900... Loss: 0.000000... Val Loss: 0.559803 Val acc: 0.952
# Epoch: 19/20... Step: 18000... Loss: 0.060294... Val Loss: 0.609998 Val acc: 0.952
# Epoch: 20/20... Step: 18100... Loss: 0.000000... Val Loss: 0.634746 Val acc: 0.953
# Epoch: 20/20... Step: 18200... Loss: 0.000000... Val Loss: 0.669943 Val acc: 0.954
# Epoch: 20/20... Step: 18300... Loss: 0.000000... Val Loss: 0.627418 Val acc: 0.952
# Epoch: 20/20... Step: 18400... Loss: 0.000000... Val Loss: 0.601761 Val acc: 0.951
# Epoch: 20/20... Step: 18500... Loss: 0.000117... Val Loss: 0.714143 Val acc: 0.948
# Epoch: 20/20... Step: 18600... Loss: 0.000000... Val Loss: 0.684856 Val acc: 0.950
# Epoch: 20/20... Step: 18700... Loss: 0.000000... Val Loss: 0.697366 Val acc: 0.950
# Epoch: 20/20... Step: 18800... Loss: 0.000001... Val Loss: 0.899881 Val acc: 0.944
# Epoch: 20/20... Step: 18900... Loss: 0.000000... Val Loss: 0.719812 Val acc: 0.949
# Epoch: 20/20... Step: 19000... Loss: 0.000000... Val Loss: 0.709852 Val acc: 0.950
# turnaround time : 77.69066905975342

# %%
# Get test data loss and accuracy

test_losses = [] # track loss
num_correct = 0


net.eval()
# iterate over test data
for inputs, labels in test_loader:

    if(train_on_gpu):
        inputs, labels = inputs.cuda(), labels.cuda()
    
    # get predicted outputs
    output = net(inputs)
    
    # calculate loss
    test_loss = criterion(output.squeeze(), labels.float())
    test_losses.append(test_loss.item())
    
    # convert output probabilities to predicted class (0 or 1)
    pred = torch.round(output.squeeze())  # rounds to the nearest integer
    
    # compare predictions to true label
    correct_tensor = pred.eq(labels.float().view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    num_correct += np.sum(correct)


# -- stats! -- ##
# avg test loss
print("Test loss: {:.3f}".format(np.mean(test_losses)))

# accuracy over all test data
test_acc = num_correct/len(test_loader.dataset)
print("Test accuracy: {:.3f}".format(test_acc))
# Out:
# Test loss: 0.651
# Test accuracy: 0.954

# %% [markdown]
# ## Test inference

# %%
title, label = next(iter(test_loader))

# %%
# text 복원
def find_title(cleaend_title, df):
    
    cleaned_title = " ".join([i for i in list(map(cleaend_title, word_list)) if '<pad>' not in i])
    
    return cleaned_title

def return_word(idx):
    word = embed_lookup.index2word[idx]
    return word

# %%
for i in range(0,133):
    inputs, labels = next(iter(test_loader))

    if(train_on_gpu):
        inputs, labels = inputs.cuda(), labels.cuda()

    # get predicted outputs
    output = net(inputs)
    preds = torch.round(output.squeeze())


    word_idx_list = inputs.cpu().numpy().tolist()
    labels = labels.cpu().numpy().tolist()
    preds = preds.cpu().detach().numpy().tolist()

    for num, word_idx in enumerate(word_idx_list):
        cleaned_title_word = list(map(return_word, word_idx))
        cleaned_title = " ".join([i for i in cleaned_title_word if '<pad>' not in i ])

        title = train_df[train_df['cleaned_prodNm'] == cleaned_title]['prodNm'].iloc[0]
        label,pred = labels[num], preds[num]

        if label == 0:
            err = '오류'
        else:
            err= '정상'

        if label == pred:
            correct = '성공'
        else:
            correct = '실패'

        print('제목 : {0}'.format(title))
        print('예측 : {0}, 정답 : {1}, \n오류 유무 : {2}, 예측 결과 : {3}'.format(pred, label, err,correct))
        print('='*100)
# Out:
# 제목 : 제주 크런치 3종(감귤,백년초,한라봉)세트 x 5 (사은품증정)
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (GIGA) Aorus X5 V4용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 팔도)불짬뽕 왕컵 115g x 16개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 부침가루(이츠웰 1K) 식자재 부침가루 기타분말가루
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 하나 진 우골농축액 505 사골농축액 840g 12ea 1box
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 리터스포트 요거트 초콜렛 100g 고급초콜렛/수입초콜렛/수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : cj햇반 컵반 레드스파이시커리덮밥 1개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 업소용 위생식탁보(특상)(90x120)280매
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 오리온 왕꿈틀이67g 껌/카라멜/젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 가공식품 선명한필름 S550-P.AF65KN용고광택필름 필름 고광
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : CJ 제일제면소 중면 900g 15입
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : [무료배송]코모리 후루츠캔디 180g X 3 과일맛캔디,일본인기사탕,수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 고바 15U570 필름 15U570용 쌀국수 고광택필름 전용필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 신미 후라이드형과자160g(20개)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 레노버 Yoga 520-14IKB Kronos용 저반사필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 무료배송 크라운 5500 마이쮸 대용량 328g x 5봉
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 발센 픽업 미니스 초코 106g 발센 픽업/초코렛/샌드/수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 마사만 커리 페이스트 50g,1~2인분
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 청정원 순창 콩 된장 900g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 킷캣 다크 146.9g X 2 초콜릿,일본인기간식,수입초콜릿
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 전용필름 필름 가공식품 쌀국수 고광택필름 NT-P580-JA06C
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (당일출고)(무료배송)해찬들 맛있게매운 태양초 고추장 500g 2
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 한성 국수 B34포스리콘2200S 전용필름 필름 가공식품 B34포
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 리터스포트 요거트 초콜렛 100g 고급초콜렛/수입초콜렛/수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 도도한나쵸오리지널(치즈맛) 155g/나쵸/과자/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 본마망 살구잼 370g 쨈,베이킹,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (당일출고)(무료배송)에코푸드 호박맛쫀디기90g(30개)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 국수 15UD340-L.AX2FK용고광택필름 전용필름 필름 LG
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : lenovo 카라스인터내셔널 전용필름 가공식품 고광택필름 국산 I
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]재커 포테이토 오리지날 140g X 5 감자칩,포테이토칩,수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : ASUS 고광택필름 고광택필름 카라스인터내셔널 쌀국수 필름 비보북
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [해외배송] 스타벅스 카라멜 시럽 1L
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 샘표 진간장금S 930ml 조미료/소스/간장/액젓
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 국산 지문방지 가공식품 LG 용 쌀국수 보호필름 저반사필름 카라스
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 양송이스프 500gX12개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 농심 맛있는 이야기 24팩 꿀꽈베기/감자깡/자갈치
# 예측 : 1.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 딸기가나슈/초콜릿만들기재료/발렌타인데이/DIY/세트
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]트롤리 사우어구미캔디 42g X 10 과일젤리,웜젤리,수입젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 윈윈 해피무 버터 10g 8개입 캐릭터과자,수입과자,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 2만원무배 에코푸드 추억의꺼벙이 1kg
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [참들고을] 종합세트 3호
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]노벨 슈퍼소다캔디 79.8g X 3 일본인기사탕,샤우어,수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]원티드 또띠아 칩스 솔트 200g X 4 토띠아칩,비스킷,수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 하리보 푸르티부시 100g 하리보/젤리/후르츠텔라/과일맛
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 즉석밥 국산 즉석밥햇반공기밥햅쌀밥쌀밥 백설 카레 즉석밥 국 컵반
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : X 쿠키 스낵 40개 스키니카카오 스넥 가공식품 쿠키 봉지과자 국
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 진간장(부천몽고 13L) 식자재 간장 진간장 말통
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 하얀설탕/하얀설탕3kg/백설탕/갈색설탕/황설탕/매실/효소
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 제주 크런치 3종(감귤,백년초,한라봉)세트 x 5 (사은품증정)
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 다빈치 스파이스 터비나도 시럽 750ml 6개세트
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] 진라면종이용기매운맛x12
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (삼성) NT200B5B-S27C용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (당일출고)(무료배송)청우 카카오닙스 쿠키 200g(8입)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 프레스코 스파게티소스(마늘+양파)685gX8개(1박스)/스파게티/
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : X60 미원 가공식품 일본산 매운맛 240g 업소용식자재 S&B
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (삼성) NTP330-JA64WR용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 샘표 잔치국수113g/잔치국수/국수
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : V5-591G 국수 ACE용 면 가공식품 필름 k48 ACER 지
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : HP Pavilion 17-X100CL용 Mirror미러 필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [엔젤쿡]건강담은 선애든해 전통방식 클린자염 저염소금 4종선물세트
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 유동 황도슬라이스 400g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 카스가이 구미100 애플 107g 24입 대카스가이/구미젤리/용량
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 민트지 페퍼민트향 115g 민트껌,허브사탕,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼성 노트북9 Always NT900X5N-KSF용 Mirror미
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] CJ크레페믹스400G밀가루
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : GE73VR7RE레이더 GE73VR 사생활보호 MSI 블랙에디션
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : HP 프로북 440 G5-1MJ83AV FD4용 거치식 Priva
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 나싱낚시용품 바이오 밑밥통 HD-40cm
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 트롤리 올인원 산딸기 20g 코스트코간식/수입젤리/수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼성 NT900X3V-A58A용 Privacy정보보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기식용유1.8L(2개입) /식용유/기름/오뚜기식용유/콩기름
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 하리보 푸르티부시 100g 하리보/젤리/후르츠텔라/과일맛
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 한성 X73용 고바 고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동원 포도잼 680g 10입 포도쨈/딸기잼/쨈
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 구미초코볼(스트로베리밀크) 40g X 5 초콜렛,구미젤리,수입젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 담터 한차 40T 차/커피/음료
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 스내츠 마늘파슬리맛 스낵 120g 스내츠/봉지과자/수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]재커 포테이토 오리지날 140g X 5 감자칩,포테이토칩,수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 엄마손파이254g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : MSI GP62M 7REX Leopard용 거치식 Privacy정
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : SB/초야식품 콩국수용콩가루 850g -1개/콩가루/콩분말
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 쇠고기다시(해인 2K)X6
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼양 간짬뽕140g 라면/봉지면/비빔면/쫄면/볶음면
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]칼파니 그린애플맛캔디 150g X 4 캔사탕,선물용캔디,고급캔디,수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 술익거든/패밀리세트/막걸리KIT/DIY
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 빅크런키82g/크런키/빅크런키/초코바
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 소스류 12EA 식자재 양념 겨자 식자재 대상 대상 840g 1B
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 해태 참ing 치즈레몬 135gx16개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 베드렌 라즈베리시럽 1000ml 2개세트
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 문구사무/목캔디(12개/아이스/롯데제과)
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (당일출고)(무료배송)농심 조청유과96g(20개)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 말랑카우밀크용기 84g 6입 껌/카라멜/젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 쌀국수 고광택필름 면 ASUS필름 UX31E-XH71용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 청우 앙상블238g(10개) 과자/전병/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 도도한나쵸오리지널(치즈맛) 155g/나쵸/과자/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동서 미떼핫초코오리지널10T 차/커피/음료
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 한성 TFG13S 82582T용 Privacy정보보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (삼성) NT200B5B-S27C용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더랜드] 팔도보부상 더덕볶음고추장500g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 국수 선명한필름 NT550P5C-S55S 삼성 쌀국수 NT550P
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼립 냉동 고구마케이크(5입)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 한알천 삼계탕1kg(16개) 초복/중복/말복
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (lenovo) E420S 4401 27U용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 니신크리스피초코밀크초코 51g 초콜렛바,초코바,시리얼바,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 키즈웰 젤리스트로우 어쏘티드 800g 스틱젤리,과일젤리,수입젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 파빌리온 15-BS563TU용 Privacy정보보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [사탕공장]땅콩캬라멜1Kg땅콩맛젤리/대용량사탕/사탕선물/업소용사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 연와사비35g(40개)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : V5-591G 국수 ACE용 면 가공식품 필름 k48 ACER 지
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 400g 스모그향 국산 가루 12봉 면 사리 당면 분말 이슬
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 보네스뻬 웰빙화과자 선물세트
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : ASUS ROG GL503VM 시리즈용 Crystal액정보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] 롯데초콜릿토이플레이포켓몬7gx8개입4볼
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] 진라면종이용기매운맛x12
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 쿠크다스커피(소) 1개 과자 간식 다과 소풍 스낵
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : [원더랜드] 10831/파우치 케찹 (식당용/3.3kgX6개)-오
# 예측 : 1.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 삼양 사리면 110g X 3
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [식사대용] 켈로그 초코첵스570g 4개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 오감자딥바베큐 75g(12개) 감자/과자/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼성 전용필름 국산 면 카라스인터내셔널 고광택필름 국수 태블릿필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 레돈도 럭셔리 크림 녹차 웨이퍼 125g 레돈도/웨이퍼스틱과자/수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 레노버 씽크패드 X1 카본 20KH005TKR용 거치식 Priva
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼성 NT900X4C-A501Z용 거치식 Privacy정보보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : HP 250 G6 시리즈용 Crystal액정보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 팬케이크 도라야끼 310g 도라야끼,일본과자,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 320-15IKB 80XL009DKR용 고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]토스티토스 크리스피라운드 또띨라 칩 283.5g X 2 또띠아칩,곡물과자,수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : CJ 하선정 남해안명품멸치액젓 500g 조미료/소스/간장/액젓
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 스낵면큰컵 90g 12입 신라면/진라면/삼양라면
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 벤토 갈릭앤스파이시 12g 6입 스틱간식,쥐포 어포,시네마,간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 다시다 미원 업소용흰물엿 물엿 9k 식재료흰물엿 가공식품 삼양사
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : Peke 포테이토칩사이다향 70g 감자칩,사이다,수입감자칩,수입과
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 생감자팩 6번들 180g/포카칩/아이들간식/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 소스류 캡사이신 캡사이신 매운맛소스 액상 550g 청우
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : cj햇반 컵반 레드스파이시커리덮밥 1개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 미니크래커 콘포타쥬맛 60g 미니크래커/콘포타쥬/수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 면사랑 냉동동치미맛 냉면육수340gX30봉
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 썬라이트 망고 180ml X 24 푸딩,젤리뽀,과일젤리,수입젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 농심 너구리소컵62g(30개)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 신안 알칼리성미네럴 삼육황토죽염300g 3개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : V5-591G 국수 ACE용 면 가공식품 필름 k48 ACER 지
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 윈윈 해피무 버터 10g 8개입 캐릭터과자,수입과자,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : GT 청정원 순창 태양초 찰고추장 골드 500g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 허쉬 라지바밀크100g /라지바밀크/허쉬라지바밀크
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] 해통령멸치분말70G조미료
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 누텔라 잼 3kg 쨈,디저트토핑,카페소스,카페시럽
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼성 전용필름 고광택필름 국수 쌀국수 국산 선명한필름 가공식품 카
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 해태 홈런볼무지방우유46g(30개) 과자/간식/스낵
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 국산 투명한필름 고광택필름 ASUSFX503VD-E4102 쌀국수
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 쌀국수 케쥬얼양말 여자 국수 여자양말 가공식품 1켤레 국산 양말
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오레가노분(신영 350g) 식재료용품
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]모닌 바닐라 시럽 1000ml 6입 디저트 토핑,카페시럽,카페소스,대용량
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 레노버 Yoga 520-14IKB Kronos용 저반사필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : SB/뚜또 코코딸기 250g -6개/젤리/푸딩
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 프런티어 코코 초콜릿웨이퍼바 84g 프런티어/수입과자/비스킷
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 다산 베이킹 제빵 재료 젤라틴 판 1K 1EA
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 카스타드 138g 12입 과자/간식/후식/스낵/비스킷
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 일본산 Cut필름 쌀국수 80TL01AXKR용 V110-15ISK
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 쌀국수 고광택필름 면 ASUS필름 UX31E-XH71용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 팔도 뽀로로 사과맛 235ml 24입 두유/베지밀/음료 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 냉동 식품 쿡앤팜 찰떡 궁합 떡갈비맛 구이 1kg 4봉지
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 일미 깐마늘500g(8개) 반찬/소세지/단무지/짱아찌 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 칸쵸 스윗밀크 47g 32입 과자/간식/쿠키
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [농심] 진짜 맛을 담은 3종x각2입(아욱된장,차돌된장,청국장)
# 예측 : 1.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 오뚜기 간편 닭곰탕 (10g*5개입) x 10개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 바몬드카레 약간매운맛 100g 40개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 황토방청국장가루(700g PET재질)
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : (당일출고)(무료배송)청정원 천일염 구운소금 500g 20입
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]모닌 라즈베리 시럽 1000ml 6입 디저트 토핑,카페시럽,카페소스,대용량
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 나가타니엔 아사게 29.2g x 5개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 농심 꿀꽈배기 30g 4입 /꿀꽈배기/꽈배기/꿀과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : SB/새한식품 메밀더국시 1kg -1개/국수/메밀
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 엠앤엠즈 피넛 150g X 3 밀크초콜릿,인기초콜렛,수입초콜릿
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 코알라키즈 초콜릿맛 16g 24입 동물모양과자,수입과자,대용량
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [고수록] 생모시 찹쌀떡 1.6kg
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (당일출고)오리온 다이제오리지널 194g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] 큰컵치즈불닭볶음면16입105Gx16
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 쌀국수 싱크패드X15th20HRCTOD 면 블루라이트컷필름 5th
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : KC/롯데제과 딸기쿠키 230g/쿠키/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 킷캣 오리지날 34.8g 10입 초코웨하스/수입초콜렛/번들
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 팔도 뽀로로 사과맛 235ml 24입 두유/베지밀/음료 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 2배사과식초900ml /사과식초/오뚜기식초
# 예측 : 1.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 국수 선명한필름 NT550P5C-S55S 삼성 쌀국수 NT550P
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 푸드) 미화합동 찌개된장 3kg(4ea)(1box)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 정보보안기 블랙에디션 카라스인터내셔널 보스몬스터 정보보안필름 쌀국
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]삼립 크루통 1kg 2입 카페재료,카페토핑,디저트 토핑,카페소스
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]삼립 바게뜨롤 600g X 2 냉동빵,카페간식,베이글,와플
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 샘표 요리에센스연두320g 조미료/소스/간장/액젓
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]플로키 체다치즈 또띨라칩 184g X 2 또띠아칩,곡물과자,수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 로아커 나폴리타너 45g 로아커/초콜렛/웨하스/수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 자일리톨오리지널코팅16g 껌/카라멜/젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 면 NT930X5J-K78 고광택필름 국산 쌀국수 삼성필름 용고광
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 구데타마 젤리 75g X 10 캐릭터젤리,어린이간식,수입젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 레노버 Yoga 520-14IKB 81C800GLKR용 Mirro
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 해표 대두식용유 1.8Lx12개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : CJ 매실청 1.025kg 9입 두유/베지밀/음료 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 설렁탕 조미료 국산 떡국 육개장 설렁탕 한박스 다시다 양념 식자재
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 청정원 순창 콩 된장 900g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : E530 전용필름 고광택필름 쌀국수 국산 가공식품 카라스인터내셔널
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : JS/일광제과 과일맛찹쌀젤리 300g -10개/젤리/제리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 후지야 연필초콜릿 27g 장난감모양사탕/초콜렛/수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 포테이토 크리스프 바베큐맛 90g/맥스/이마트/수입 과자/감자 감자칩/프링글스/나쵸칩
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 농심 닭다리 후라이드 치킨맛 66g/2개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]페레로로쉐 5T X 3 밀크초콜릿,고급초콜렛,수입초콜릿
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : SB/2/고향만두 치즈갈비교자(315gX2봉) -3개/만두/냉동
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더랜드] 두레 미니돈까스1kg 2개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 타피오카펄(코만 400g) 식자재 타피오카펄 기타분말가루
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 춘향골사람들 대청 1,350g 한과선물세트
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 컵밥 오삼 불고기 덮밥 280g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 짜장(분말) 100g/짜장/분말/식품
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [1위] 원가판매 국산 쌀분말(볶음)200g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 캐빈디쉬하비 체리맛캔디 200g 캔사탕/고급사탕/선물/수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : SB/뚜또 코코딸기 250g -6개/젤리/푸딩
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 킷캣 다크맛 33.9g 40입 초코렛,초코릿다크,대용량,박스
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 범용 시럽 펌프 포모나/다빈치/토라니/베네치아/CJ메티에
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] (맛있는포장마차2종세트)직화구이불닭x양념오돌뼈
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : Lenovo 110-15ISK-80UD00CSKR용 Crystal
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 소스류 12EA 식자재 양념 겨자 식자재 대상 대상 840g 1B
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : Q/농심 매콤달콤양념치킨면 150g -32개/라면
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : SB/뚜또 코코딸기 250g -6개/젤리/푸딩
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 고추장 된장 양념 쌈장 장류 해찬들 CJ 가공식품 낫또 청국장
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : Bluelight 면 X542UA-DM473T용 카라스인터내셔널
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 농심 양파깡 83g 20입 스낵과자 무료배송
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 면 NT930X5J-K78 고광택필름 국산 쌀국수 삼성필름 용고광
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 본마망 살구잼 370g 쨈,베이킹,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 건강식품 very 분말 국수 면 가루랑 당면 가루랑 천연식품 사리
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 세진식품 해바라기씨 100g 안주/건어물/견과류1
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 하림 고향삼계탕 880g 12입 국밥/안주/즉석식품 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동원 자연한입군밤80g(40개) 간식/과자/맛밤
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 맛고을 유가엿450g /유가엿/엿/사탕/맛고을엿
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 향신료조제품 국산 이엔푸드 미원 시치미 이엔 조미료 업소용식자재
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 이슬나라 혼합 생강가루 양념 450gX12개 식자재 가루 생강가루
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 신미 김맛160g(20개) 스낵과자 무료배송
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 카레 냉동 고향 육개장600g-묶음배송 누룽지 미얀마산 간식 죽
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 제면용 고급밀가루(곰표 20K) 식자재 밀가루 고급밀가루 포대 믹
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 포도쨈500g(12개) 과자/간식/빵쨈 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 아름아침 제주감귤유과 1kg
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 맛사랑 식자재 조미료 복합조미식품 핵산 MSG 2Kg 6EA
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] 진라면종이용기매운맛x12
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 월남쌈 다시다 뉴 조미료 메밀국수 네모당면 양념 300g IEN
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 모닌 레몬 시럽 1000ml 카페시럽,카페토핑,과일시럽
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 한성 X54 보스몬스터 Lv.85W용 고바 저반사필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 농심 너구리소컵62g(30개)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 면사랑 콩국수3kg  3개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 하림 삼계탕(반마리)600g(20개) 국밥/안주/즉석식품 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 미니 더 심슨바닐라 275g X 2 캐릭터과자,비스켓,수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : ASUS Vivobook S14 S406UA-BV021용 블랙에디
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 해태 버터링302g/버터링/애기과자/버터링과자/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 리터스포트 요거트 초콜렛 100g 고급초콜렛/수입초콜렛/수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 화과방 빙수팥 파우치 3kg 빙수,빙수토핑,카페토핑,홈카페
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 대용량/식당용/업소용/참기름/향미유/참웰빙기름1.8리터
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 320-15IKB 80XL009DKR용 고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (당일출고)(무료배송)동원 살코기참치 100g 60입
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 차단필름 보안기 저반사 면 사생활보호 정보보안필름 쌀국수 검은색
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 와사비 소스 250G
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : LOT 100 구미망고 10g 5입 과일젤리/야외활동/수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 푸드) 미화합동 찌개된장 3kg(4ea)(1box)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 맥심 모카골드20T 커피/차/꿀
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더풀데이] (맛있는포장마차2종세트)직화구이불닭x양념오돌뼈
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 액정보호필름 면 일본산 국수 V510-15IKB 쌀국수 거울필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 맛기름 B 식자재 (1.8LX12개) 치악산
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 마사만 커리 페이스트 50g,1~2인분
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 시루아네 감사2-1선물세트(100g씩15개1.5kg)+쇼핑백보자기
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동원 포도잼 680g 10입 포도쨈/딸기잼/쨈
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 밀키타 멜론밀크 캔디 80g 20입 밀키타/수입사탕/대용량/박스
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]포모나 카라멜 소스 2kg 6입 디저트 토핑,초코릿,카페소스,대용량
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]크림오 밀크 108g X 10 비스켓,비스킷,수입과자
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 촉촉한초코칩 120g/초코칩/아이들간식/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동원 리얼 밀크 1개, 녹차 1개, 인절미 1개 스프레드 3개
# 예측 : 1.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 실패
# ...
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 백설 허브맛솔트 마늘맛 55g
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 독일 비타하임 포도당 캔디 6개 딸기/레몬/혼합과일맛
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 로얄단스크_버터쿠키/오트밀쿠키1kg/수입과자/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 캐빈디쉬하비 체리맛캔디 200g 캔사탕/고급사탕/선물/수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 썬라이트 망고 180ml X 24 푸딩,젤리뽀,과일젤리,수입젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 즉석밥 국산 즉석밥햇반공기밥햅쌀밥쌀밥 백설 카레 즉석밥 국 컵반
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 유자차 1kg 9입 커피/차/꿀 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 국산 흰물엿 가공식품 조미료 다시다 이온물엿 말통 양념 10KgX
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (삼성) NTP330-JA64WR용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 한성 B35 ForceRecon 3327W용 고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 청우 젤리코 젤리믹스 80g(24입) 껌/캬라멜/젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼양 스리라차볶음면 135g X 5
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 빙빙 딸기 53.4g 아이스크림콘스넥,어린이간식,수입간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동원 마일드참치 150g 캔참치/캠핑/동원참치/사조참치
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 가공식품 HD올레포빅필름 GL503VM-ED220용 쌀국수 면 R
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [해외배송] 노세노세 쇼유바타 간장. 명란. 카레. 고기된장 버터
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 유피 버거젤리 96g 구미젤리/후르츠텔라/유피/버거
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 필름 고광택필름 카라스인터내셔널 싱크패드 면 레노버 전용필름 선명
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동원 리얼킹새우 55g 160입 소시지/소시지/맥스봉
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 스케이터 미니 주먹밥 만들기
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 면사랑 콩국수3kg  3개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : CW/청우 밀키샤벳 720g/쭈쭈바/얼려먹는젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 제주 초콜릿종합세트(감귤,백년초,녹차,한라봉) 50개입 x 4box (사은품증정)
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : GT 청정원 순창 태양초 찰고추장 골드 500g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 타피오카펄(코만 400g) 식자재 타피오카펄 기타분말가루
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 문구사무/프링글스 (오리지날/110g)
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 농심 얼큰장칼국수103g/장칼국수/칼국수
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (당일출고)(무료배송)CJ 고메 크림베이컨포테이토 180g 15입
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 동원 리얼 밀크 1개, 녹차 1개, 인절미 1개 스프레드 3개
# 예측 : 1.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 천년의유산 전통국간장 500ML 맛간장
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 한성 U58 ForceRecon 6757S2W용 저반사필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 알토이즈 페파민트향 캔디 50g 6입 캔사탕/고급사탕/수입사탕/대
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 식재료 소면국수(청수 1K)X15
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 구워만든 곡물 그래로21 180g(10gX18) 웰빙간식 파머스맘
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : LG 그램 15ZB970-GP5BML용 고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (HP) ProBook440G1-J7V44PA용고광택필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : Bluelight 국수 Cut필름 가공식품 쌀국수 국산 액정필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : (냉동)청우모듬전 400gX6개-묶음배송(3가능)
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 땅콩강정 147g/땅콩강정/강정/땅콩/간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 젤리데이 포도 392g x 5개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 김맛 후리가께 500g
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 델원 혼합 푸딩 120g 4입 스틱젤리,젤리뽀,푸딩,젤리스틱
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 담터 한차 40T 차/커피/음료
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 델리퀸 후라이드치킨II 750g2개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : HP 250 G6-2G1T용 Crystal액정보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : X60 미원 가공식품 일본산 매운맛 240g 업소용식자재 S&B
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 포테이토 크리스프 바베큐맛 90g/바비큐 BBQ 크리스피
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 에버휩 휘핑크림 1030g 카페토핑,카페음료,라떼,칵테일
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 1200 빼빼로 바닐라 블랙쿠키32g x20
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 삼천리 떡볶이스낵65g(30개) 과자/간식/떡볶이
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 유리창시트지 UV차단 베이직 스트라이프 DC-BHPU-89008D
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 벤토 갈릭앤스파이시 12g 6입 스틱간식,쥐포 어포,시네마,간식
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 롯데 칸쵸 파티팩 대용량 864g 16개입 과자/간식
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : HP 파빌리온 15-BC229TX용 Mirror미러 필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : Always 보호필름 액정필름 저반사필름 카라스인터내셔널 노트북9
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더랜드] 524574/레몬시럽 (1LX6개)- 모닌
# 예측 : 0.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 세진식품 깐호두50g 안주/건어물/견과류1
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [무료배송]노벨 슈퍼소다캔디 79.8g X 3 일본인기사탕,샤우어,수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : SB/포유에프엔비 삼계탕 1kg/즉석삼계탕/즉석국
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 사과향초코펜/초콜릿만들기재료/발렌타인데이/DIY/막대과자만들기
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [에이라이프]권기옥명인 웃말상촌식품 선물세트 명인궁중어육장
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : [원더랜드] 문구사무/김치사발면 작은사발(86g24개/BOX/농심
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : BAMBOO 누가크래커 112g X 3 샌드,비스켓,비스킷,수입과
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 자스민차(엠푸드 454g)X6
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : ASUS Zenbook UX31E용 고바 저반사필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오뚜기 2배사과식초900ml /사과식초/오뚜기식초
# 예측 : 1.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 실패
# ====================================================================================================
# 제목 : 동원 자연한입군밤80g(40개) 간식/과자/맛밤
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : MSI GP63 Leopard 8RE용 Crystal액정보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 쁘띠첼 미초 자몽 900ml/홍초/흑초/음료수/파인애플식초/
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 향신료 세이지럽드 식자재 (200gX1개) 신영
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : KC/초초 초콜릿바 600g/초콜릿/초콜렛
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 청우 천연 향신료 로즈 마리 가루 분말 240g 1EA
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 면속초아바이먹태10미 6통
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 칼파니 허브맛캔디 35g X 5 캔사탕,선물용캔디,고급캔디,수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 광천김 파래식탁(대)55g(20개) 김 무료배송
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 본오본 블랑코 15g 토피/카라멜/초콜렛/수입사탕
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : LG 그램 15ZD980-HX76K용 Privacy정보보호필름
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 3분 데리야끼 치킨 150G x 6개
# 예측 : 1.0, 정답 : 1,
# 오류 유무 : 정상, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 해태 아이비135g(20개) 비스켓/크래커/스틱 무료배송
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : KC/선미식품 마이짱 복숭아맛 660g/캔디/카라멜
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# 제목 : 오리온 젤리데이포도 49g(32개) 껌/캬라멜/젤리
# 예측 : 0.0, 정답 : 0,
# 오류 유무 : 오류, 예측 결과 : 성공
# ====================================================================================================
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-e69084af6a49> in <module>
#      18         cleaned_title = " ".join([i for i in cleaned_title_word if '<pad>' not in i ])
#      19
# ---> 20         title = train_df[train_df['cleaned_prodNm'] == cleaned_title]['prodNm'].iloc[0]
#      21         label,pred = labels[num], preds[num]
#      22
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2155
#    2156             # validate the location
# -> 2157             self._validate_integer(key, axis)
#    2158
#    2159             return self._get_loc(key, axis=axis)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2086         len_axis = len(self.obj._get_axis(axis))
#    2087         if key >= len_axis or key < -len_axis:
# -> 2088             raise IndexError("single positional indexer is out-of-bounds")
#    2089
#    2090     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds
